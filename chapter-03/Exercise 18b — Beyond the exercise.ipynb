# %%
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# # Beyond 1
#
# Ignore the `password` and `groupid` fields, such that they don't appear in the data frame.

# %%
# Note that we name all columns, and then only use a subset of them
df = pd.read_csv('../data/linux-etc-passwd.txt', 
                 sep=':', comment='#', header=None,
                 usecols=['username', 'userid', 'name', 'homedir', 'shell'],
                names=['username', 'password', 'userid', 'groupid', 'name', 'homedir', 'shell'])
df
# Out:
#               username  userid                                name  \
# 0                 root       0                                root
# 1               daemon       1                              daemon
# 2                  bin       2                                 bin
# 3                  sys       3                                 sys
# 4                 sync       4                                sync
# 5                games       5                               games
# 6                  man       6                                 man
# 7                   lp       7                                  lp
# 8                 mail       8                                mail
# 9                 news       9                                news
# 10                uucp      10                                uucp
# 11               proxy      13                               proxy
# 12            www-data      33                            www-data
# 13              backup      34                              backup
# 14                list      38                Mailing List Manager
# 15                 irc      39                                ircd
# 16               gnats      41  Gnats Bug-Reporting System (admin)
# 17              nobody   65534                              nobody
# 18              syslog     101                                 NaN
# 19          messagebus     102                                 NaN
# 20           landscape     103                                 NaN
# 21                 jci     955                                 NaN
# 22                sshd     104                                 NaN
# 23                user    1000                             user,,,
# 24              reuven    1001                 Reuven M. Lerner,,,
# 25             postfix     105                                 NaN
# 26              colord     106  colord colour management daemon,,,
# 27            postgres     107         PostgreSQL administrator,,,
# 28             dovecot     108              Dovecot mail server,,,
# 29            dovenull     109               Dovecot login user,,,
# 30            postgrey     110                                 NaN
# 31        debian-spamd     111                                 NaN
# 32            memcache     113                        Memcached,,,
# 33              genadi    1002               Genadi Reznichenko,,,
# 34               shira    1003                   Shira Friedman,,,
# 35               atara    1004            Atara Lerner-Friedman,,,
# 36              shikma    1005           Shikma Lerner-Friedman,,,
# 37               amotz    1006            Amotz Lerner-Friedman,,,
# 38               mysql     114                     MySQL Server,,,
# 39              clamav     115                                 NaN
# 40              amavis     116               AMaViS system user,,,
# 41            opendkim     117                                 NaN
# 42        gitlab-redis     999                                 NaN
# 43         gitlab-psql     998                                 NaN
# 44                 git    1007                           GitLab,,,
# 45           opendmarc     118                                 NaN
# 46  dkim-milter-python     119                                 NaN
# 47              deploy    1008                           Deploy,,,
# 48               redis     112                     redis server,,,
#
#                         homedir              shell
# 0                         /root          /bin/bash
# 1                     /usr/sbin  /usr/sbin/nologin
# 2                          /bin  /usr/sbin/nologin
# 3                          /dev  /usr/sbin/nologin
# 4                          /bin          /bin/sync
# 5                    /usr/games  /usr/sbin/nologin
# 6                /var/cache/man  /usr/sbin/nologin
# 7                /var/spool/lpd  /usr/sbin/nologin
# 8                     /var/mail  /usr/sbin/nologin
# 9               /var/spool/news  /usr/sbin/nologin
# 10              /var/spool/uucp  /usr/sbin/nologin
# 11                         /bin  /usr/sbin/nologin
# 12                     /var/www  /usr/sbin/nologin
# 13                 /var/backups  /usr/sbin/nologin
# 14                    /var/list  /usr/sbin/nologin
# 15                /var/run/ircd  /usr/sbin/nologin
# 16               /var/lib/gnats  /usr/sbin/nologin
# 17                 /nonexistent  /usr/sbin/nologin
# 18                 /home/syslog         /bin/false
# 19                /var/run/dbus         /bin/false
# 20           /var/lib/landscape         /bin/false
# 21                    /home/jci          /bin/bash
# 22                /var/run/sshd  /usr/sbin/nologin
# 23                   /home/user          /bin/bash
# 24                 /home/reuven          /bin/bash
# 25           /var/spool/postfix         /bin/false
# 26              /var/lib/colord         /bin/false
# 27          /var/lib/postgresql          /bin/bash
# 28             /usr/lib/dovecot         /bin/false
# 29                 /nonexistent         /bin/false
# 30            /var/lib/postgrey         /bin/false
# 31        /var/lib/spamassassin            /bin/sh
# 32                 /nonexistent         /bin/false
# 33                 /home/genadi          /bin/bash
# 34                  /home/shira          /bin/bash
# 35                  /home/atara          /bin/bash
# 36                 /home/shikma          /bin/bash
# 37                  /home/amotz          /bin/bash
# 38                 /nonexistent         /bin/false
# 39              /var/lib/clamav         /bin/false
# 40              /var/lib/amavis            /bin/sh
# 41            /var/run/opendkim         /bin/false
# 42        /var/opt/gitlab/redis       /bin/nologin
# 43   /var/opt/gitlab/postgresql            /bin/sh
# 44                    /home/git          /bin/bash
# 45           /var/run/opendmarc         /bin/false
# 46  /var/run/dkim-milter-python         /bin/false
# 47                 /home/deploy          /bin/bash
# 48               /var/lib/redis         /bin/false

# %% [markdown]
# # Beyond 2
#
# Unix systems typically reserve user IDs below 1000 to special accounts.  Show the non-special usernames in this `passwd` file.

# %%
df = pd.read_csv('../data/linux-etc-passwd.txt',
                 sep=':', comment='#', header=None,
                names=['username', 'password', 'userid', 'groupid', 'name', 'homedir', 'shell'])

df[df['userid'] >= 1000]
# Out:
#    username password  userid  groupid                       name  \
# 17   nobody        x   65534    65534                     nobody
# 23     user        x    1000     1000                    user,,,
# 24   reuven        x    1001     1001        Reuven M. Lerner,,,
# 33   genadi        x    1002     1003      Genadi Reznichenko,,,
# 34    shira        x    1003     1004          Shira Friedman,,,
# 35    atara        x    1004     1005   Atara Lerner-Friedman,,,
# 36   shikma        x    1005     1006  Shikma Lerner-Friedman,,,
# 37    amotz        x    1006     1007   Amotz Lerner-Friedman,,,
# 44      git        x    1007     1008                  GitLab,,,
# 47   deploy        x    1008     1011                  Deploy,,,
#
#          homedir              shell
# 17  /nonexistent  /usr/sbin/nologin
# 23    /home/user          /bin/bash
# 24  /home/reuven          /bin/bash
# 33  /home/genadi          /bin/bash
# 34   /home/shira          /bin/bash
# 35   /home/atara          /bin/bash
# 36  /home/shikma          /bin/bash
# 37   /home/amotz          /bin/bash
# 44     /home/git          /bin/bash
# 47  /home/deploy          /bin/bash

# %% [markdown]
# # Beyond 3
#
# Immediately after logging into a Unix system, a command interpreter, known as a "shell," fires up. What are the different shells in this file?

# %%
# The `unique` method does this for us, returning a NumPy array
df['shell'].unique()
# Out:
# array(['/bin/bash', '/usr/sbin/nologin', '/bin/sync', '/bin/false',
#        '/bin/sh', '/bin/nologin'], dtype=object)
