# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
import glob

all_dfs = []

all_filenames = glob.glob('../data/*,*.csv')

for one_filename in all_filenames:
    print(f'Loading {one_filename}...')
    city, state = one_filename.removeprefix('../data/').removesuffix('.csv').split(',')
    one_df = pd.read_csv(one_filename,
                     usecols=[1, 2, 19],
                     names=['max_temp', 'min_temp', 'precipMM'],
                     header=0)
    one_df['city'] = city.replace('+', ' ').title()
    one_df['state'] = state.upper()
    all_dfs.append(one_df)

df = pd.concat(all_dfs)
# Out:
# Loading ../data/san+francisco,ca.csv...
# Loading ../data/new+york,ny.csv...
# Loading ../data/springfield,ma.csv...
# Loading ../data/boston,ma.csv...
# Loading ../data/springfield,il.csv...
# Loading ../data/albany,ny.csv...
# Loading ../data/los+angeles,ca.csv...
# Loading ../data/chicago,il.csv...

# %%
sns.relplot(x='max_temp', y='min_temp', data=df.loc[df['city'] == 'Chicago'])

# %%
sns.relplot(x='max_temp', y='min_temp', data=df)

# %%
sns.relplot(x='max_temp', y='min_temp', data=df, hue='city')

# %%
sns.relplot(x='max_temp', y='min_temp', data=df, hue='city', style='city')

# %%
sns.relplot(x='max_temp',
            y='min_temp',
            data=df,
            hue='state', style='city')

# %%
sns.relplot(x='max_temp',
            y='min_temp',
            data=df,
            hue='state',
            row='city')

# %%
sns.relplot(x='max_temp',
            y='min_temp',
            data=df,
            hue='state', kind='line')
# Out:
# /usr/local/lib/python3.10/site-packages/seaborn/_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rr/0mnyyv811fs5vyp22gf4fxk00000gn/T/ipykernel_1822/405529506.py in <module>
# ----> 1 sns.relplot(x='max_temp',
#       2             y='min_temp',
#       3             data=df,
#       4             hue='state', kind='line')
#
# /usr/local/lib/python3.10/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.10/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1034
#    1035     # Draw the plot
# -> 1036     g.map_dataframe(func, **plot_kws)
#    1037
#    1038     # Label the axes
#
# /usr/local/lib/python3.10/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     775
#     776             # Draw the plot
# --> 777             self._facet_plot(func, ax, args, kwargs)
#     778
#     779         # For axis labels, prefer to use positional args for backcompat
#
# /usr/local/lib/python3.10/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# /usr/local/lib/python3.10/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.10/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# /usr/local/lib/python3.10/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# /usr/local/lib/python3.10/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# /usr/local/lib/python3.10/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1688             self._setitem_with_indexer_split_path(indexer, value, name)
#    1689         else:
# -> 1690             self._setitem_single_block(indexer, value, name)
#    1691
#    1692     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1927             # setting for extensionarrays that store dicts. Need to decide
#    1928             # if it's worth supporting that.
# -> 1929             value = self._align_series(indexer, Series(value))
#    1930
#    1931         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2082                 if obj.ndim == 2 and is_empty_indexer(indexer[0], ser._values):
#    2083                     return ser._values.copy()
# -> 2084                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2085
#    2086                 # single indexer
#
# /usr/local/lib/python3.10/site-packages/pandas/core/series.py in reindex(self, *args, **kwargs)
#    4670                 )
#    4671             kwargs.update({"index": index})
# -> 4672         return super().reindex(**kwargs)
#    4673
#    4674     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# /usr/local/lib/python3.10/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4972
#    4973         # perform the reindex on the axes
# -> 4974         return self._reindex_axes(
#    4975             axes, level, limit, tolerance, method, fill_value, copy
#    4976         ).__finalize__(self, method="reindex")
#
# /usr/local/lib/python3.10/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4992
#    4993             axis = self._get_axis_number(a)
# -> 4994             obj = obj._reindex_with_indexers(
#    4995                 {axis: [new_index, indexer]},
#    4996                 fill_value=fill_value,
#
# /usr/local/lib/python3.10/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5038
#    5039             # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5040             new_data = new_data.reindex_indexer(
#    5041                 index,
#    5042                 indexer,
#
# /usr/local/lib/python3.10/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677         # some axes don't allow reindexing with dups
#     678         if not allow_dups:
# --> 679             self.axes[axis]._validate_can_reindex(indexer)
#     680
#     681         if axis >= self.ndim:
#
# /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    4105         # trying to reindex on an axis with duplicates
#    4106         if not self._index_as_unique and len(indexer):
# -> 4107             raise ValueError("cannot reindex on an axis with duplicate labels")
#    4108
#    4109     def reindex(
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
# Reset the index to 0-
df = df.reset_index(drop=True)

# %%
sns.relplot(x='max_temp',
            y='min_temp',
            data=df,
            hue='state', kind='line')

# %%
sns.relplot(x='max_temp',
            y='min_temp',
            data=df,
            hue='state',
            kind='line',
            row='city')

# %%
sns.displot(df, x='max_temp')

# %%
sns.displot(data=df, x='max_temp', hue='city', row='state')

# %%
sns.catplot(x='city', y='max_temp', data=df)

# %%
sns.catplot(x='city', y='max_temp', data=df, kind='box')

# %%
sns.catplot(x='city', y='max_temp', data=df, kind='violin')

# %%
sns.displot(x='max_temp', data=df)

# %%
sns.displot(x='max_temp', data=df, hue='city')

# %%
sns.displot(x='max_temp', data=df, hue='city', row='city')
